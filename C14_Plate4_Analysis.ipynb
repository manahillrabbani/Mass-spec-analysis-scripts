# %%
# Vial: A1
# Composition: E12 

m_1 = 188.2 # Triamine E mass
m_2 = 134.04 # Dialdehyde 1 mass
m_3 = 206.09 # Dialdehyde 2 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions
positive_integer_solutions = find_solutions()
print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 1 =", solution[1], ", Dialdehyde 2 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: A2
# Composition: E13 

m_1 = 188.2
 # Triamine E mass
m_2 = 134.04 # Dialdehyde 1 mass
m_3 = 195.97 # Dialdehyde 3 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 1 =", solution[1], ", Dialdehyde 3 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: A3
# Composition: E14 

m_1 = 188.2
 # Triamine E mass
m_2 = 134.04 # Dialdehyde 1 mass
m_3 = 134.04 # Dialdehyde 4 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 1 =", solution[1], ", Dialdehyde 4 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: A4
# Composition: E15 

m_1 = 188.2
 # Triamine E mass
m_2 = 134.04 # Dialdehyde 1 mass
m_3 = 206.00 # Dialdehyde 5 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 1 =", solution[1], ", Dialdehyde 5 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: A5
# Composition: E16 

m_1 = 188.2
 # Triamine E mass
m_2 = 134.04 # Dialdehyde 1 mass
m_3 = 210.07 # Dialdehyde 6 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 1 =", solution[1], ", Dialdehyde 6 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: A6
# Composition: E17 

m_1 = 188.2
 # Triamine E mass
m_2 = 134.04 # Dialdehyde 1 mass
m_3 = 234.07 # Dialdehyde 7 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 1 =", solution[1], ", Dialdehyde 7 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: A7
# Composition: E18 

m_1 = 188.2 # Triamine E mass
m_2 = 134.04 # Dialdehyde 1 mass
m_3 = 236.06 # Dialdehyde 8 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 1 =", solution[1], ", Dialdehyde 8 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: A8
# Composition: E19 

m_1 = 188.2 # Triamine E mass
m_2 = 134.04 # Dialdehyde 1 mass
m_3 = 139.99 # Dialdehyde 9 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 1 =", solution[1], ", Dialdehyde 9 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: B1
# Composition: E 1 10 

m_1 = 188.2 # Triamine E mass
m_2 = 134.04 # Dialdehyde 1 mass
m_3 = 134.04 # Dialdehyde 10 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 1 =", solution[1], ", Dialdehyde 10 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: B2
# Composition: E 1 14 

m_1 = 188.2 # Triamine E mass
m_2 = 134.04 # Dialdehyde 1 mass
m_3 = 188.06 # Dialdehyde 14 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 1 =", solution[1], ", Dialdehyde 14 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: B3
# Composition: E 1 15 

m_1 = 188.2 # Triamine E mass
m_2 = 134.04 # Dialdehyde 1 mass
m_3 = 284.10 # Dialdehyde 15 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 1 =", solution[1], ", Dialdehyde 15 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: B4
# Composition: E23 

m_1 = 188.2
 # Triamine E mass
m_2 = 206.09 # Dialdehyde 2 mass
m_3 = 195.97 # Dialdehyde 3 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 2 =", solution[1], ", Dialdehyde 3 =", solution[2], ", Mass =", solution[3])

# %% [markdown]
# ### Vials B5-C8:

# %%
# Vial: B5
# Composition: E24 

m_1 = 188.2
 # Triamine E mass
m_2 = 206.09 # Dialdehyde 2 mass
m_3 = 134.04 # Dialdehyde 4 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 2 =", solution[1], ", Dialdehyde 4 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: B6
# Composition: E25 

m_1 = 188.2
 # Triamine E mass
m_2 = 206.09 # Dialdehyde 2 mass
m_3 = 206.00 # Dialdehyde 5 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 2 =", solution[1], ", Dialdehyde 5 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: B7
# Composition: E26 

m_1 = 188.2
 # Triamine E mass
m_2 = 206.09 # Dialdehyde 2 mass
m_3 = 210.07 # Dialdehyde 6 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 2 =", solution[1], ", Dialdehyde 6 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: B8
# Composition: E27 

m_1 = 188.2
 # Triamine E mass
m_2 = 206.09 # Dialdehyde 2 mass
m_3 = 234.07 # Dialdehyde 7 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 2 =", solution[1], ", Dialdehyde 7 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: C1
# Composition: E28 

m_1 = 188.2 # Triamine E mass
m_2 = 206.09 # Dialdehyde 2 mass
m_3 = 236.06 # Dialdehyde 8 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 2 =", solution[1], ", Dialdehyde 8 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: C2
# Composition: E29 

m_1 = 188.2 # Triamine E mass
m_2 = 206.09 # Dialdehyde 2 mass
m_3 = 139.99 # Dialdehyde 9 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 2 =", solution[1], ", Dialdehyde 9 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: C3
# Composition: E 2 10 

m_1 = 188.2 # Triamine E mass
m_2 = 206.09 # Dialdehyde 2 mass
m_3 = 134.04 # Dialdehyde 10 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 2 =", solution[1], ", Dialdehyde 10 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: C4
# Composition: E 2 14 

m_1 = 188.2 # Triamine E mass
m_2 = 206.09 # Dialdehyde 2 mass
m_3 = 188.06 # Dialdehyde 14 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 2 =", solution[1], ", Dialdehyde 14 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: C5
# Composition: E 2 15 

m_1 = 188.2 # Triamine E mass
m_2 = 206.09 # Dialdehyde 2 mass
m_3 = 284.10 # Dialdehyde 15 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 2 =", solution[1], ", Dialdehyde 15 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: C6
# Composition: E34 

m_1 = 188.2
 # Triamine E mass
m_2 = 195.97 # Dialdehyde 3 mass
m_3 = 134.04 # Dialdehyde 4 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 3 =", solution[1], ", Dialdehyde 4 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: C7
# Composition: E35 

m_1 = 188.2
 # Triamine E mass
m_2 = 195.97 # Dialdehyde 3 mass
m_3 = 206.00 # Dialdehyde 5 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 3 =", solution[1], ", Dialdehyde 5 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: C8
# Composition: E36 

m_1 = 188.2
 # Triamine E mass
m_2 = 195.97 # Dialdehyde 3 mass
m_3 = 210.07 # Dialdehyde 6 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 3 =", solution[1], ", Dialdehyde 6 =", solution[2], ", Mass =", solution[3])

# %% [markdown]
# ### Vials D1-E4:

# %%
# Vial: D1
# Composition: E37 

m_1 = 188.2
 # Triamine E mass
m_2 = 195.97 # Dialdehyde 3 mass
m_3 = 234.07 # Dialdehyde 7 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 3 =", solution[1], ", Dialdehyde 7 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: D2
# Composition: E38 

m_1 = 188.2 # Triamine E mass
m_2 = 195.97 # Dialdehyde 3 mass
m_3 = 236.06 # Dialdehyde 8 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 3 =", solution[1], ", Dialdehyde 8 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: D3
# Composition: E39 

m_1 = 188.2 # Triamine E mass
m_2 = 195.97 # Dialdehyde 3 mass
m_3 = 139.99 # Dialdehyde 9 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 3 =", solution[1], ", Dialdehyde 9 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: D4
# Composition: E 3 10 

m_1 = 188.2 # Triamine E mass
m_2 = 195.97 # Dialdehyde 3 mass
m_3 = 134.04 # Dialdehyde 10 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 3 =", solution[1], ", Dialdehyde 10 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: D5
# Composition: E 3 14 

m_1 = 188.2 # Triamine E mass
m_2 = 195.97 # Dialdehyde 3 mass
m_3 = 188.06 # Dialdehyde 14 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 3 =", solution[1], ", Dialdehyde 14 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: D6
# Composition: E 3 15 

m_1 = 188.2 # Triamine E mass
m_2 = 195.97 # Dialdehyde 3 mass
m_3 = 284.10 # Dialdehyde 15 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 3 =", solution[1], ", Dialdehyde 15 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: D7
# Composition: E45 

m_1 = 188.2
 # Triamine E mass
m_2 = 134.04 # Dialdehyde 4 mass
m_3 = 206.00 # Dialdehyde 5 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 4 =", solution[1], ", Dialdehyde 5 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: D8
# Composition: E46 

m_1 = 188.2
 # Triamine E mass
m_2 = 134.04 # Dialdehyde 4 mass
m_3 = 210.07 # Dialdehyde 6 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 4 =", solution[1], ", Dialdehyde 6 =", solution[2], ", Mass =", solution[3])

# %% [markdown]
# ### Vials E1-F4:

# %%
# Vial: E1
# Composition: E47 

m_1 = 188.2
 # Triamine E mass
m_2 = 134.04 # Dialdehyde 4 mass
m_3 = 234.07 # Dialdehyde 7 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 4 =", solution[1], ", Dialdehyde 7 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: E2
# Composition: E48 

m_1 = 188.2 # Triamine E mass
m_2 = 134.04 # Dialdehyde 4 mass
m_3 = 236.06 # Dialdehyde 8 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 4 =", solution[1], ", Dialdehyde 8 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: E3
# Composition: E49 

m_1 = 188.2 # Triamine E mass
m_2 = 134.04 # Dialdehyde 4 mass
m_3 = 139.99 # Dialdehyde 9 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 4 =", solution[1], ", Dialdehyde 9 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: E4
# Composition: E 4 10 

m_1 = 188.2 # Triamine E mass
m_2 = 134.04 # Dialdehyde 4 mass
m_3 = 134.04 # Dialdehyde 10 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 4 =", solution[1], ", Dialdehyde 10 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: E5
# Composition: E 4 14 

m_1 = 188.2 # Triamine E mass
m_2 = 134.04 # Dialdehyde 4 mass
m_3 = 188.06 # Dialdehyde 14 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 4 =", solution[1], ", Dialdehyde 14 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: E6
# Composition: E 4 15 

m_1 = 188.2 # Triamine E mass
m_2 = 134.04 # Dialdehyde 4 mass
m_3 = 284.10 # Dialdehyde 15 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 4 =", solution[1], ", Dialdehyde 15 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: E7
# Composition: E56 

m_1 = 188.2
 # Triamine E mass
m_2 = 206.00 # Dialdehyde 5 mass
m_3 = 210.07 # Dialdehyde 6 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 5 =", solution[1], ", Dialdehyde 6 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: E8
# Composition: E57 

m_1 = 188.2
 # Triamine E mass
m_2 = 206.00 # Dialdehyde 5 mass
m_3 = 234.07 # Dialdehyde 7 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 5 =", solution[1], ", Dialdehyde 7 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: F1
# Composition: E58 

m_1 = 188.2 # Triamine E mass
m_2 = 206.00 # Dialdehyde 5 mass
m_3 = 236.06 # Dialdehyde 8 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 5 =", solution[1], ", Dialdehyde 8 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: F2
# Composition: E59 

m_1 = 188.2 # Triamine E mass
m_2 = 206.00 # Dialdehyde 5 mass
m_3 = 139.99 # Dialdehyde 9 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 5 =", solution[1], ", Dialdehyde 9 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: F3
# Composition: E 5 10 

m_1 = 188.2 # Triamine E mass
m_2 = 206.00 # Dialdehyde 5 mass
m_3 = 134.04 # Dialdehyde 10 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 5 =", solution[1], ", Dialdehyde 10 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: F4
# Composition: E 5 14 

m_1 = 188.2 # Triamine E mass
m_2 = 206.00 # Dialdehyde 5 mass
m_3 = 188.06 # Dialdehyde 14 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 5 =", solution[1], ", Dialdehyde 14 =", solution[2], ", Mass =", solution[3])

# %%
# Vial: F5
# Composition: E 5 15 

m_1 = 188.2 # Triamine E mass
m_2 = 206.00 # Dialdehyde 5 mass
m_3 = 284.10 # Dialdehyde 15 mass

def find_solutions():
    solutions = []
    for x in range(0, 100):  # Triamine - Adjust the range as needed
        for y in range(0, 100):  # Dialdehyde- Adjust the range as needed
            for z in range(0, 100):  # Dialdehyde - Adjust the range as needed
                m = m_1*x + m_2*y + m_3*z - (3*x)*18.01 #calculate mass of cage
                m = m + 1 # Add H mass
                if 2*y + 2*z == 3*x and 1 < m < 6000:
                    solutions.append((x, y, z, m))
    solutions.sort(key=lambda x: x[3])  # Sort solutions by value
    return solutions

positive_integer_solutions = find_solutions()

print("Positive integer solutions:")
for solution in positive_integer_solutions:
    print("Triamine E =", solution[0], ", Dialdehyde 5 =", solution[1], ", Dialdehyde 15 =", solution[2], ", Mass =", solution[3])
